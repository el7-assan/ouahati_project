# %%
import numpy as np 
import pandas as pd

# %%
crops={
  "جزر":{ "emoji":"Carrot.pnj", "latin":"Carrot", "water":"منخفض", "days":"70-80 يوم", "diff":"سهل" },
  "بصل":{ "emoji":"Onion.pnj", latin:"Onion",  water:"منخفض", days:"90-120 يوم", diff:"سهل" },
  "ثوم":{ "emoji":"Garlic.pnj", latin:"Garlic", water:"منخفض", days:"180-210 يوم", diff:"سهل" },
  "سبانخ":{ "emoji":"Spinach.pnj", latin:"Spinach",water:"منخفض", days:"40-50 يوم", diff:"سهل" },
  "كزبرة":{"emoji":"Coriander.pnj", latin:"Coriander",water:"منخفض",days:"30-45 يوم",diff:"سهل"},
  "سلق":{"emoji":"Chard.pnj", latin:"Chard",  water:"متوسط", days:"50-60 يوم", diff:"سهل" },
  "خس":{"emoji":"Lettuce.pnj", latin:"Lettuce",water:"متوسط", days:"45-60 يوم", diff:"سهل" },
  "بازلاء":{"emoji":"Peas.pnj", latin:"Peas",   water:"متوسط", days:"60-70 يوم", diff:"متوسط"},
  "فجل":{"emoji":"Radish.pnj", latin:"Radish", water:"منخفض", days:"25-30 يوم", diff:"سهل" },
  "طماطم":{"emoji":"Tomato.pnj", latin:"Tomato", water:"مرتفع", days:"80-100 يوم", diff:"متوسط"},
  "فلفل":{"emoji":"Pepper.pnj", latin:"Pepper", water:"متوسط", days:"90-120 يوم", diff:"متوسط"},
  "خيار":{"emoji":"Cucumber.pnj", latin:"Cucumber",water:"مرتفع",days:"55-65 يوم",diff:"سهل"},
  "كوسة":{"emoji":"Zucchini.pnj", latin:"Zucchini",water:"متوسط",days:"50-60 يوم",diff:"سهل"},
  "باذنجان":{"emoji":"Eggplant.pnj", latin:"Eggplant",water:"مرتفع",days:"80-100 يوم",diff:"متوسط"},
  "بطيخ":{"emoji":"Watermelon.pnj", latin:"Watermelon",water:"مرتفع",days:"80-90 يوم",diff:"متوسط"},
  "شمام":{"emoji":"Melon.pnj", latin:"Melon",  water:"مرتفع", days:"75-85 يوم", diff:"متوسط"},
  "قرع":{"emoji":"Pumpkin.pnj", latin:"Pumpkin",water:"متوسط", days:"90-110 يوم",diff:"سهل"},
  "لوبياء":{"emoji":"Cowpea.pnj", latin:"Cowpea", water:"منخفض", days:"65-75 يوم", diff:"سهل"},
  "فول سوداني":{"emoji":"Groundnut.pnj", latin:"Groundnut",water:"متوسط",days:"100-130 يوم",diff:"متوسط"},
  "تمر مجهول":{"emoji":"Medjool_Date.pnj", latin:"Medjool Date",water:"متوسط",days:"سنوي",diff:"خبرة"},
  "حناء":{"emoji":"Henna.pnj", latin:"Henna",  water:"منخفض", days:"سنوي",      diff:"سهل"},
  "نخيل":{"emoji":"Palm.pnj", latin:"Palm",   water:"متوسط", days:"سنوي",      diff:"خبرة"},
  "الفصة":{"emoji":"Alfalfa.pnj", latin:"Alfalfa",water:"مرتفع",days:"سنوي",diff:"سهل"},
  "تمر بوفقوس":{"emoji":"Boufegous.pnj", latin:"Boufegous",water:"متوسط",days:"سنوي",diff:"خبرة"},
  "تمر أحمر":{"emoji":"Red_Date.pnj", latin:"Red Date",water:"متوسط",days:"سنوي",     diff:"خبرة"},
  "لفت":{"emoji":"Turnip.pnj", latin:"Turnip", water:"منخفض", days:"45-60 يوم", diff:"سهل"},
  "بروكلي":{"emoji":"Broccoli.pnj", latin:"Broccoli",water:"متوسط",days:"80-100 يوم",diff:"متوسط"},
  "كرنب":{"emoji":"Cabbage.pnj", latin:"Cabbage",water:"متوسط", days:"70-100 يوم",diff:"متوسط"},
  "شلغم":{"emoji":"Parsnip.pnj", latin:"Parsnip",water:"منخفض", days:"50-70 يوم",diff:"سهل"},
  "بطاطا":{"emoji":"Potato.pnj", latin:"Potato", water:"متوسط", days:"90-120 يوم",diff:"متوسط"},
  "شبت":{"emoji":"Dill.pnj", latin:"Dill",   water:"منخفض", days:"40-60 يوم", diff:"سهل"},
  "نعناع":{ "emoji":"Mint.pnj", latin:"Mint",   water:"متوسط", days:"سنوي",      diff:"سهل"},
  "إكليل الجبل":{ "emoji":"Rosemary.pnj", latin:"Rosemary",water:"منخفض",days:"سنوي",diff:"سهل"},
  "تمر بوسكري":{ "emoji":"Bouskri.pnj", latin:"Bouskri",water:"متوسط",days:"سنوي",   diff:"خبرة"},
  "تمر فجري":{ "emoji":"Figuig_Date.pnj", latin:"Figuig Date",water:"منخفض",days:"سنوي", diff:"خبرة"},
  "بقدونس":{ "emoji":"Parsley.pnj", latin:"Parsley",water:"منخفض", days:"70-90 يوم", diff:"سهل"},
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 crops={
# ----> 2   "جزر":{ emoji:"Carrot.pnj", latin:"Carrot", water:"منخفض", days:"70-80 يوم", diff:"سهل" },
#       3   "بصل":{ emoji:"Onion.pnj", latin:"Onion",  water:"منخفض", days:"90-120 يوم", diff:"سهل" },
#       4   "ثوم":{ emoji:"Garlic.pnj", latin:"Garlic", water:"منخفض", days:"180-210 يوم", diff:"سهل" },
#       5   "سبانخ":{ emoji:"Spinach.pnj", latin:"Spinach",water:"منخفض", days:"40-50 يوم", diff:"سهل" },
#       6   "كزبرة":{ emoji:"Coriander.pnj", latin:"Coriander",water:"منخفض",days:"30-45 يوم",diff:"سهل"},
#       7   "سلق":{ emoji:"Chard.pnj", latin:"Chard",  water:"متوسط", days:"50-60 يوم", diff:"سهل" },
#       8   "خس":{ emoji:"Lettuce.pnj", latin:"Lettuce",water:"متوسط", days:"45-60 يوم", diff:"سهل" },
# ...

# %%
months = [
  { id:1, name:"يناير", season:"شتاء", icon:"❄️", climate:"بارد وجاف",
    seasonTitle:"موسم الشتاء — زراعة شتوية",
    seasonDesc:"الظروف المناخية مناسبة جداً لزراعة الخضروات الجذرية والورقية. الحرارة المنخفضة تحمي من الآفات وتحسن طعم المحاصيل.",
    seasonTag:"✅ موسم مثالي للزراعة",
    heroDesc:"موسم الزراعة الشتوية — مثالي للخضروات الجذرية والأعشاب العطرية في الواحات",
    alert:"درجات الحرارة الليلية ستنخفض — احمِ الشتلات الحساسة بالتغطية",
    alertTitle:"تنبيه برد ليلي",
    water:35, waterLabel:"منخفض — 35%",
    crops:["جزر","بصل","ثوم","سبانخ","كزبرة"],
    tips:[
      {label:"توقيت الزرع",text:"ابدأ الزرع في منتصف الشهر بعد انتهاء أبرد الليالي",type:""},
      {label:"مقاومة الصقيع",text:"غطِّ الشتلات الصغيرة بقماش خيش ليلاً في المناطق المرتفعة",type:"gold"},
      {label:"التسميد",text:"أضف سماداً عضوياً قبل الزرع بأسبوع لتحضير التربة",type:""},
      {label:"الري",text:"ري خفيف صباحاً فقط — 2 مرة أسبوعياً كافية في هذا البرد",type:"blue"},
    ]
  },
  { id:2, name:"فبراير", season:"شتاء", icon:"🌦️", climate:"بارد ومعتدل",
    seasonTitle:"نهاية الشتاء — تحضير لربيع مبكر",
    seasonDesc:"وقت رائع لزراعة البذور داخل المنازل وتحضير الأصناف الربيعية. ابدأ شتلات الطماطم والفلفل داخلياً.",
    seasonTag:"✅ جيد للزراعة الداخلية",
    heroDesc:"نهاية موسم الشتاء — حان وقت تحضير شتلات الربيع ومتابعة المحاصيل الشتوية",
    alert:"موجة برودة محتملة في منتصف الشهر — راقب نشرات الطقس",
    alertTitle:"تنبيه مناخي",
    water:30, waterLabel:"منخفض جداً — 30%",
    crops:["جزر","سلق","خس","بازلاء","فجل"],
    tips:[
      {label:"الشتلات الربيعية",text:"ابدأ تشتيل الطماطم والفلفل داخل البيت الآن",type:""},
      {label:"الحماية من الصقيع",text:"خطر الصقيع لا يزال قائماً — استمر في التغطية الليلية",type:"gold"},
      {label:"تهوية التربة",text:"قلب التربة للسماح بتهويتها قبل موسم النمو",type:""},
      {label:"الري",text:"ري خفيف — مرتان أسبوعياً في الصباح الباكر",type:"blue"},
    ]
  },
  { id:3, name:"مارس", season:"ربيع", icon:"🌸", climate:"معتدل ومثالي",
    seasonTitle:"موسم الربيع — قمة الزراعة",
    seasonDesc:"أفضل وقت للزراعة في الواحات. الطقس المعتدل والنهارات الأطول يوفران ظروفاً مثالية لمعظم المحاصيل.",
    seasonTag:"🌟 أفضل موسم زراعي",
    heroDesc:"الربيع قادم — الموسم الذهبي للزراعة في واحات درعة-تافيلالت",
    alert:"ابدأ زراعة الطماطم والفلفل الآن للحصول على أفضل موسم",
    alertTitle:"الموسم المثالي",
    water:55, waterLabel:"متوسط — 55%",
    crops:["طماطم","فلفل","خيار","كوسة","باذنجان"],
    tips:[
      {label:"المسافات",text:"اترك 60سم بين شتلات الطماطم و40سم للفلفل",type:""},
      {label:"الدعم",text:"ضع دعائم خشبية لشتلات الطماطم من البداية",type:"gold"},
      {label:"التسميد",text:"سماد متوازن كل أسبوعين مع بداية ظهور الثمار",type:""},
      {label:"الري",text:"ري منتظم — 3 مرات أسبوعياً مع ارتفاع الحرارة التدريجي",type:"blue"},
    ]
  },
  { id:4, name:"أبريل", season:"ربيع", icon:"🌿", climate:"معتدل ومثالي",
    seasonTitle:"ربيع متأخر — نمو قوي",
    seasonDesc:"استمر في رعاية المحاصيل الربيعية وابدأ التخطيط للمحاصيل الصيفية. راقب الآفات مع ارتفاع الحرارة.",
    seasonTag:"✅ موسم ممتاز",
    heroDesc:"نمو قوي في الواحات — تابع محاصيلك الربيعية وخطط للصيف",
    alert:"ابدأ مراقبة الآفات مع ارتفاع درجات الحرارة في النهار",
    alertTitle:"تنبيه الآفات",
    water:65, waterLabel:"متوسط — 65%",
    crops:["طماطم","فلفل","خيار","بطيخ","شمام"],
    tips:[
      {label:"مكافحة الآفات",text:"استخدم الرش بالصابون السائل لمكافحة المن طبيعياً",type:"gold"},
      {label:"التقليم",text:"قلم الأفرع الجانبية للطماطم لتركيز الطاقة في الثمار",type:""},
      {label:"التسقيف",text:"ابدأ التخطيط لتظليل خفيف للمحاصيل الحساسة",type:""},
      {label:"الري",text:"ري يومي الصباح — تجنب الري في وقت الذروة",type:"blue"},
    ]
  },
  { id:5, name:"مايو", season:"صيف مبكر", icon:"☀️", climate:"دافئ ومشمس",
    seasonTitle:"صيف مبكر — محاصيل الحرارة",
    seasonDesc:"حرارة الصيف مناسبة لمحاصيل البطيخ والقرعيات. تحضر واحات تافيلالت لموسم التمر المبكر.",
    seasonTag:"⚠️ راقب درجات الحرارة",
    heroDesc:"بداية موسم الحرارة — البطيخ والقرعيات تزدهر في واحاتنا",
    alert:"تجنب الزراعة الجديدة في منتصف الشهر — انتظر انتهاء موجة الحر المتوقعة",
    alertTitle:"تحذير حرارة",
    water:75, waterLabel:"مرتفع — 75%",
    crops:["بطيخ","شمام","قرع","لوبياء","فول سوداني"],
    tips:[
      {label:"تظليل النخيل",text:"تأكد من سلامة أغطية التظليل قبل موجة الحر",type:"gold"},
      {label:"الري الصباحي",text:"الري قبل الساعة 8 صباحاً فقط — الري النهاري يحرق الجذور",type:"blue"},
      {label:"الفراش الأخضر",text:"ضع طبقة من القش حول النباتات لتحتفظ بالرطوبة",type:""},
      {label:"مراقبة التربة",text:"تحقق من رطوبة التربة يومياً في العمق 10سم",type:""},
    ]
  },
  { id:6, name:"يونيو", season:"صيف", icon:"🌞", climate:"حار وجاف",
    seasonTitle:"ذروة الصيف — حماية المحاصيل",
    seasonDesc:"أشد أشهر السنة حرارة. ركز على صيانة ما هو موجود وترشيد المياه. موسم نضج التمور يقترب.",
    seasonTag:"⚠️ موسم حماية لا زراعة",
    heroDesc:"ذروة الصيف — حافظ على ما لديك وركز على ترشيد المياه",
    alert:"موجة حر شديدة متوقعة — وفر المياه واحمِ جميع المحاصيل",
    alertTitle:"🔴 تحذير حرارة شديدة",
    water:90, waterLabel:"مرتفع جداً — 90%",
    crops:["تمر مجهول","حناء","نخيل","جت (برسيم)"],
    tips:[
      {label:"ترشيد المياه",text:"استخدم نظام التنقيط — يوفر حتى 40% من المياه مقارنة بالغمر",type:"blue"},
      {label:"تهوية النخيل",text:"تأكد من تهوية جيدة حول قواعد النخيل لتجنب الأمراض",type:""},
      {label:"التوقيت",text:"كل العمل الزراعي قبل 9 صباحاً أو بعد 5 مساءً",type:"gold"},
      {label:"الطوارئ",text:"احتفظ باحتياطي مياه لحالات الطوارئ",type:""},
    ]
  },
  { id:7, name:"يوليو", season:"صيف", icon:"🌴", climate:"حار جداً",
    seasonTitle:"موسم التمر يقترب",
    seasonDesc:"رغم الحرارة الشديدة، هذا وقت مراقبة نضج التمور وتحضير الحصاد. قلل الزراعة الجديدة للحد الأدنى.",
    seasonTag:"🌴 استعداد لحصاد التمر",
    heroDesc:"نخيل التمر يتجهز للحصاد — تفقد عناقيدك وجهز معدات الحصاد",
    alert:"تفقد عناقيد التمر أسبوعياً لمراقبة مرحلة النضج",
    alertTitle:"موسم التمر قادم",
    water:95, waterLabel:"مرتفع جداً — 95%",
    crops:["تمر مجهول","تمر بوفيقوس","نخيل أحمر"],
    tips:[
      {label:"مراقبة التمر",text:"ابدأ فحص درجة حلاوة التمر أسبوعياً من منتصف الشهر",type:""},
      {label:"تحضير الحصاد",text:"جهز الأكياس والسلالم وأدوات الحصاد مسبقاً",type:"gold"},
      {label:"الري قبل الحصاد",text:"قلل الري 10 أيام قبل الحصاد لتحسين جودة التمر",type:"blue"},
      {label:"التخزين",text:"جهز غرفة تخزين باردة وجافة للتمر المحصود",type:""},
    ]
  },
  { id:8, name:"أغسطس", season:"صيف", icon:"🌅", climate:"حار مع رياح",
    seasonTitle:"حصاد التمور الكبير",
    seasonDesc:"موسم الذروة لحصاد تمور المجهول الشهيرة. المنطقة تشهد نشاطاً زراعياً كبيراً وأسواقاً موسمية.",
    seasonTag:"🌟 موسم الحصاد الكبير",
    heroDesc:"حصاد تمور المجهول — المنتج الأشهر في واحات تافيلالت يصل لذروته",
    alert:"تجنب حصاد التمر في ساعات الذروة — الجودة تتأثر بالحرارة الشديدة",
    alertTitle:"نصيحة الحصاد",
    water:85, waterLabel:"مرتفع — 85%",
    crops:["تمر مجهول","تمر بوسكري","تمر فجري"],
    tips:[
      {label:"وقت الحصاد",text:"اجمع التمر في الصباح الباكر (6-9 ص) للحفاظ على الجودة",type:"gold"},
      {label:"التمييز",text:"افرز التمر فور الحصاد: درجة أولى ثانية ثالثة",type:""},
      {label:"البيع المبكر",text:"تواصل مع التجار مسبقاً قبل ذروة السوق",type:""},
      {label:"التخزين",text:"35% من التمر يمكن تجفيفه وتخزينه لستة أشهر",type:"blue"},
    ]
  },
  { id:9, name:"سبتمبر", season:"خريف", icon:"🍂", climate:"معتدل ومنعش",
    seasonTitle:"نهاية الحصاد — بداية الخريف",
    seasonDesc:"الحرارة تبدأ بالانخفاض — فرصة ذهبية لزراعة الخضروات الخريفية وإعداد التربة للموسم القادم.",
    seasonTag:"✅ وقت التجديد الزراعي",
    heroDesc:"الخريف يعود — حان وقت إعادة إحياء الواحة بمحاصيل جديدة",
    alert:"ابدأ تحضير التربة الآن للاستفادة من مطر الخريف المحتمل",
    alertTitle:"فرصة المطر",
    water:50, waterLabel:"متوسط — 50%",
    crops:["جزر","لفت","بروكلي","كرنب","شلغم"],
    tips:[
      {label:"تجديد التربة",text:"أضف سماداً عضوياً وقلب التربة لتهويتها بعد الصيف",type:""},
      {label:"محاصيل الخريف",text:"ابدأ زراعة الخضروات الجذرية في أوائل الشهر",type:""},
      {label:"حفظ البذور",text:"احفظ بذور من أفضل محاصيل هذا الموسم",type:"gold"},
      {label:"الري",text:"ابدأ تقليل الري تدريجياً مع انخفاض الحرارة",type:"blue"},
    ]
  },
  { id:10, name:"أكتوبر", season:"خريف", icon:"🌾", climate:"جيد ومعتدل",
    seasonTitle:"موسم الخريف الذهبي",
    seasonDesc:"أحد أفضل الشهور للزراعة بعد الربيع. الطقس مثالي ومعظم المحاصيل تنمو بسرعة وجودة عالية.",
    seasonTag:"🌟 موسم زراعة ممتاز",
    heroDesc:"الموسم الذهبي الثاني — الخريف يقدم ظروفاً مثالية للزراعة",
    alert:"استغل هذا الشهر المثالي — أفضل وقت للزراعة بعد الربيع",
    alertTitle:"موسم مثالي",
    water:45, waterLabel:"معتدل — 45%",
    crops:["بصل","ثوم","بطاطا","جزر","خس"],
    tips:[
      {label:"المسافات المثالية",text:"بصل: 15سم — ثوم: 10سم — جزر: 5سم بين البذور",type:""},
      {label:"العمق الصحيح",text:"ابذر على عمق 2-3 سم ولا تغطِ كثيراً",type:""},
      {label:"الدورة الزراعية",text:"لا تزرع نفس العائلة النباتية في نفس المكان كل سنة",type:"gold"},
      {label:"الري",text:"ري منتظم مرتين أسبوعياً — الأرض يجب أن تكون رطبة لا مشبعة",type:"blue"},
    ]
  },
  { id:11, name:"نوفمبر", season:"خريف متأخر", icon:"🌙", climate:"بارد ليلاً",
    seasonTitle:"خريف متأخر — تحضير الشتاء",
    seasonDesc:"الليالي تبرد تدريجياً. وقت جيد لزراعة الثوم والبصل وبعض الأعشاب العطرية التي تفضل البرود.",
    seasonTag:"✅ موسم الأعشاب والبصليات",
    heroDesc:"الليالي الباردة تعود — موسم الثوم والأعشاب العطرية في الواحات",
    alert:"ابدأ حماية النباتات الحساسة من البرود الليلي المتزايد",
    alertTitle:"تنبيه برودة",
    water:35, waterLabel:"منخفض — 35%",
    crops:["ثوم","بصل","شبت","نعناع","إكليل الجبل"],
    tips:[
      {label:"زراعة الثوم",text:"نوفمبر هو الوقت المثالي لزراعة الثوم في المنطقة",type:""},
      {label:"الأعشاب",text:"النعناع والشبت يزدهران في برودة الشتاء",type:""},
      {label:"تغطية الشتلات",text:"استخدم القماش الأبيض لحماية النباتات الحساسة ليلاً",type:"gold"},
      {label:"تقليل الري",text:"ري مرة واحدة أسبوعياً فقط — الشتاء يحتاج ماء أقل",type:"blue"},
    ]
  },
  { id:12, name:"ديسمبر", season:"شتاء", icon:"⛄", climate:"بارد وجاف",
    seasonTitle:"موسم الراحة والتخطيط",
    seasonDesc:"أبرد شهر في السنة. وقت مثالي للتخطيط للموسم القادم ومراجعة التجربة وصيانة الأدوات والبنية التحتية.",
    seasonTag:"📋 وقت التخطيط والصيانة",
    heroDesc:"الشتاء وقت التأمل والتخطيط — جهز خطتك الزراعية لعام جديد",
    alert:"درجات الحرارة قد تصل للتجمد ليلاً في المناطق المرتفعة — احمِ نخيلك",
    alertTitle:"تحذير تجمد",
    water:25, waterLabel:"منخفض جداً — 25%",
    crops:["سبانخ","كزبرة","بقدونس","ثوم"],
    tips:[
      {label:"مراجعة الموسم",text:"دوّن ملاحظاتك: ما نجح وما فشل هذا الموسم",type:""},
      {label:"صيانة الأدوات",text:"نظف وصنِّن جميع الأدوات قبل الموسم الجديد",type:"gold"},
      {label:"طلبات الدعم",text:"الآن الوقت لتقديم طلبات الدعم الحكومي لموسم 2025",type:""},
      {label:"الري الشتوي",text:"الري مرة واحدة فقط كل 10 أيام للنباتات الشتوية",type:"blue"},
    ]
  },
];
